# %% [markdown]
# <a href="https://www.kaggle.com/code/antonasnitsky/naya-ds2022-pandas-project-video-games-sales?scriptVersionId=107415842" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Video Games Sales EDA

# %% [markdown]
# # # Data preparation
# Let;s load main libraries and the data from CSV fle.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sbs

df = pd.read_csv('/kaggle/input/videogamesales/vgsales.csv')

# %% [markdown]
# # # Common data explanation
# Dataset includes sales data for numerous video games in different regions by years, platforms, genres and publishers.

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# Let's see how much games are competing in each genre.

# %%
games_by_genre = df.groupby("Genre")[["Name"]].count()

# %%
games_by_genre.plot(kind='pie', y='Name')
# Out:
# <AxesSubplot:ylabel='Name'>

# %%
df.groupby(["Name", "Year"])[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]].sum()
# Out:
#                                                 NA_Sales  EU_Sales  JP_Sales  \
# Name                                    Year
# '98 Koshien                             1998.0      0.15      0.10      0.12
# .hack//G.U. Vol.1//Rebirth              2006.0      0.00      0.00      0.17
# .hack//G.U. Vol.2//Reminisce            2006.0      0.11      0.09      0.00
# .hack//G.U. Vol.2//Reminisce (jp sales) 2006.0      0.00      0.00      0.16
# .hack//G.U. Vol.3//Redemption           2007.0      0.00      0.00      0.17
# ...                                                  ...       ...       ...
# thinkSMART FAMILY!                      2010.0      0.03      0.00      0.00
# thinkSMART: Chess for Kids              2011.0      0.01      0.00      0.00
# uDraw Studio                            2010.0      1.67      0.58      0.00
# uDraw Studio: Instant Artist            2011.0      0.09      0.10      0.00
# ¡Shin Chan Flipa en colores!            2007.0      0.00      0.00      0.14
#
# ...
